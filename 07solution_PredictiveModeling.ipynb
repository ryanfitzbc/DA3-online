# %%
#Run the following code to print multiple outputs from a cell
get_ipython().ast_node_interactivity = 'all'

# %% [markdown]
# # Predictive Modeling
#
# ## Importing & Profiling the Data
# The file we'll be using today is "creditCardDefaultReduced.csv". It contains information about Taiwanese credit card customers and includes the following fields:
#
# * Payment: Paid or Missed
# * Card: Type of card
# * Education: Education level
# * Marriage: Marital status
# * Age: Age of customer
# * BillAmt_1: Amount of last bill
# * PayAmt_1: Amount of last payment
# * Pay_0: Number of months delayed
# * Limit_Bal: Balance of the customer's credit card limit
#
# Import the file, "creditCardDefaultReduced.csv", and save it in a variable called `df`. Then, do some initial data profiling of the data.

# %%
import pandas as pd
df = pd.read_csv("creditCardDefaultReduced.csv")
df
# Out:
#        Limit_Bal    Education Marriage  Age   Pay_0  Bill_Amt1  Pay_Amt1  \
# 0          20000   University  married   24  Delay2       3913         0
# 1         120000   University   single   26  ontime       2682         0
# 2          90000   University   single   34  Delay0      29239      1518
# 3          50000   University  married   37  Delay0      46990      2000
# 4          50000   University  married   57  ontime       8617      2000
# ...          ...          ...      ...  ...     ...        ...       ...
# 29995     220000  High school  married   39  Delay0     188948      8500
# 29996     150000  High school   single   43  ontime       1683      1837
# 29997      30000   University   single   37  Delay4       3565         0
# 29998      80000  High school  married   41  Delay1      -1645     85900
# 29999      50000   University  married   46  Delay0      47929      2078
#
#       Payment    Card
# 0      Missed  Normal
# 1      Missed  Normal
# 2        Paid  Normal
# 3        Paid  Normal
# 4        Paid    Gold
# ...       ...     ...
# 29995    Paid    Gold
# 29996    Paid    Gold
# 29997  Missed    Gold
# 29998  Missed    Gold
# 29999  Missed    Gold
#
# [30000 rows x 9 columns]

# %%
df.dtypes
df.isna().sum()
# Out:
# Limit_Bal     int64
# Education    object
# Marriage     object
# Age           int64
# Pay_0        object
# Bill_Amt1     int64
# Pay_Amt1      int64
# Payment      object
# Card         object
# dtype: object
# Limit_Bal    0
# Education    0
# Marriage     0
# Age          0
# Pay_0        0
# Bill_Amt1    0
# Pay_Amt1     0
# Payment      0
# Card         0
# dtype: int64

# %%
df.describe()
# Out:
#             Limit_Bal           Age      Bill_Amt1       Pay_Amt1
# count    30000.000000  30000.000000   30000.000000   30000.000000
# mean    167484.322667     35.485500   51223.330900    5663.580500
# std     129747.661567      9.217904   73635.860576   16563.280354
# min      10000.000000     21.000000 -165580.000000       0.000000
# 25%      50000.000000     28.000000    3558.750000    1000.000000
# 50%     140000.000000     34.000000   22381.500000    2100.000000
# 75%     240000.000000     41.000000   67091.000000    5006.000000
# max    1000000.000000     79.000000  964511.000000  873552.000000

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='Limit_Bal', ylabel='Limit_Bal'>,
#         <Axes: xlabel='Age', ylabel='Limit_Bal'>,
#         <Axes: xlabel='Bill_Amt1', ylabel='Limit_Bal'>,
#         <Axes: xlabel='Pay_Amt1', ylabel='Limit_Bal'>],
#        [<Axes: xlabel='Limit_Bal', ylabel='Age'>,
#         <Axes: xlabel='Age', ylabel='Age'>,
#         <Axes: xlabel='Bill_Amt1', ylabel='Age'>,
#         <Axes: xlabel='Pay_Amt1', ylabel='Age'>],
#        [<Axes: xlabel='Limit_Bal', ylabel='Bill_Amt1'>,
#         <Axes: xlabel='Age', ylabel='Bill_Amt1'>,
#         <Axes: xlabel='Bill_Amt1', ylabel='Bill_Amt1'>,
#         <Axes: xlabel='Pay_Amt1', ylabel='Bill_Amt1'>],
#        [<Axes: xlabel='Limit_Bal', ylabel='Pay_Amt1'>,
#         <Axes: xlabel='Age', ylabel='Pay_Amt1'>,
#         <Axes: xlabel='Bill_Amt1', ylabel='Pay_Amt1'>,
#         <Axes: xlabel='Pay_Amt1', ylabel='Pay_Amt1'>]], dtype=object)

# %%
df["Payment"].value_counts(normalize = True)
df["Education"].value_counts(normalize = True)
df["Marriage"].value_counts(normalize = True)
# Out:
# Payment
# Paid      0.7788
# Missed    0.2212
# Name: proportion, dtype: float64
# Education
# University         0.467667
# Graduate school    0.352833
# High school        0.163900
# other              0.015600
# Name: proportion, dtype: float64
# Marriage
# single     0.532133
# married    0.455300
# other      0.010767
# unknown    0.001800
# Name: proportion, dtype: float64

# %% [markdown]
# We want to explain the "Payment" column, so let's try to make a histogram to see if it's normally distributed:

# %%
df["Payment"].hist()
# Out:
# <Axes: >

# %% [markdown]
# This is not continuous data, so we'll use a classification model to predict whether someone will make or miss their payment.

# %% [markdown]
# ## Outcome and Features
#
# We need to create two inputs for machine learning models:
# * Outcome: A single column of data that the model will try to explain
# * Features: One or more columns of data that explain the outcome
#
# We'll experiment with different models today, but all require an outcome and set of features.
#
# ### Outcome
#
# Outcome is relatively simple since it's a single column:

# %%
outcome = df["Payment"]
outcome
# Out:
# 0        Missed
# 1        Missed
# 2          Paid
# 3          Paid
# 4          Paid
#           ...
# 29995      Paid
# 29996      Paid
# 29997    Missed
# 29998    Missed
# 29999    Missed
# Name: Payment, Length: 30000, dtype: object

# %% [markdown]
# ### Features
#
# We'll handle 2 types of data differently -- numeric and factors (categorical variables).
#
# #### Numeric Features
# First, the data has numeric variables like `Limit_Bal` and `Age`:

# %%
numericFeatures = df[["Limit_Bal", "Bill_Amt1", "Pay_Amt1", "Age"]]
numericFeatures
# Out:
#        Limit_Bal  Bill_Amt1  Pay_Amt1  Age
# 0          20000       3913         0   24
# 1         120000       2682         0   26
# 2          90000      29239      1518   34
# 3          50000      46990      2000   37
# 4          50000       8617      2000   57
# ...          ...        ...       ...  ...
# 29995     220000     188948      8500   39
# 29996     150000       1683      1837   43
# 29997      30000       3565         0   37
# 29998      80000      -1645     85900   41
# 29999      50000      47929      2078   46
#
# [30000 rows x 4 columns]

# %% [markdown]
# #### Categorical Features
# Second, the data has categorical columns.
# * Despite all the discussion about new data (image, audio, video, etc.), models only work with numbers. Data needs to be numeric
# * But we really, really, **really** want to use non-numeric data
# * Some examples:
#   - Colors? Red, green, blue
#   - Day of the week? Sunday, Monday, Tuesday, ..., Saturday
#   - School? Boston College, Notre Dame, Boston University
#   - ...and many others
# * What do we do?
#
# Some data, like `Marriage` is a set of discrete values:

# %%
df["Marriage"].value_counts()
# Out:
# Marriage
# single     15964
# married    13659
# other        323
# unknown       54
# Name: count, dtype: int64

# %% [markdown]
# `get_dummies` converts this data to multiple columns of true (1) and false (0) values:

# %%
dummiesMarriage = pd.get_dummies(df["Marriage"], prefix = "Marriage", drop_first = True)
dummiesMarriage
# Out:
#        Marriage_other  Marriage_single  Marriage_unknown
# 0               False            False             False
# 1               False             True             False
# 2               False             True             False
# 3               False            False             False
# 4               False            False             False
# ...               ...              ...               ...
# 29995           False            False             False
# 29996           False             True             False
# 29997           False             True             False
# 29998           False            False             False
# 29999           False            False             False
#
# [30000 rows x 3 columns]

# %% [markdown]
# Now you try...create dummy variables for the `Card` and `Pay_0` variables:

# %%
dummiesCard = pd.get_dummies(df["Card"], prefix = "Card", drop_first = True)
dummiesPay_0 = pd.get_dummies(df["Pay_0"], prefix = "Pay_0", drop_first = True)

# %% [markdown]
# Now we need to combine all our features into a single variable using the `concat` command:

# %%
features = pd.concat([numericFeatures, dummiesMarriage, dummiesPay_0, dummiesCard], axis = 1)
features
# Out:
#        Limit_Bal  Bill_Amt1  Pay_Amt1  Age  Marriage_other  Marriage_single  \
# 0          20000       3913         0   24           False            False
# 1         120000       2682         0   26           False             True
# 2          90000      29239      1518   34           False             True
# 3          50000      46990      2000   37           False            False
# 4          50000       8617      2000   57           False            False
# ...          ...        ...       ...  ...             ...              ...
# 29995     220000     188948      8500   39           False            False
# 29996     150000       1683      1837   43           False             True
# 29997      30000       3565         0   37           False             True
# 29998      80000      -1645     85900   41           False            False
# 29999      50000      47929      2078   46           False            False
#
#        Marriage_unknown  Pay_0_Delay1  Pay_0_Delay2  Pay_0_Delay3  \
# 0                 False         False          True         False
# 1                 False         False         False         False
# 2                 False         False         False         False
# 3                 False         False         False         False
# 4                 False         False         False         False
# ...                 ...           ...           ...           ...
# 29995             False         False         False         False
# 29996             False         False         False         False
# 29997             False         False         False         False
# 29998             False          True         False         False
# 29999             False         False         False         False
#
#        Pay_0_Delay4  Pay_0_Delay5  Pay_0_Delay6  Pay_0_Delay7  Pay_0_Delay8+  \
# 0             False         False         False         False          False
# 1             False         False         False         False          False
# 2             False         False         False         False          False
# 3             False         False         False         False          False
# 4             False         False         False         False          False
# ...             ...           ...           ...           ...            ...
# 29995         False         False         False         False          False
# 29996         False         False         False         False          False
# 29997          True         False         False         False          False
# 29998         False         False         False         False          False
# 29999         False         False         False         False          False
#
#        Pay_0_ontime  Pay_0_unknown  Card_Normal
# 0             False          False         True
# 1              True          False         True
# 2             False          False         True
# 3             False          False         True
# 4              True          False        False
# ...             ...            ...          ...
# 29995         False          False        False
# 29996          True          False        False
# 29997         False          False        False
# 29998         False          False        False
# 29999         False          False        False
#
# [30000 rows x 18 columns]

# %% [markdown]
# *The `axis = 1` parameter tells the `concat` function to combine by columns instead of by rows.*
#
# Now, we have 2 variables:
# * `outcome` contains the single column of data that we will try to explain
# * `features` contains multiple columns of data that we believe explains the `outcome` variable

# %% [markdown]
# ## Partitioning the Data
# When we have sufficient data, we want to use only part of the data to train the model. By keeping part of the data as test data, we can better evaluate how well the model works.
#
# ![image.png](attachment:f6e49498-488d-4ef2-95a1-9a27809a0402.png)

# %% [markdown]
# Why split the data?
#
# What if you were trying to create a model to separate the dots?
#
# ![image.png](attachment:5c2849f1-95e7-428e-8fe6-e68c2757c945.png)
#
# This model would be perfect on red, but not so great on blue:
#
# ![image.png](attachment:935a74b9-42e1-4771-ae45-3e7b18f7f677.png)
#
# And this model would be perfect on blue, but not on red:
#
# ![image.png](attachment:4237130e-5a81-4515-9e4c-cf8d56644490.png)
#
# This, of course, is the perfect model, but it's perfect only for these specific dots (overfitting):
#
# ![image.png](attachment:5d876b0d-ede4-4085-8d9d-864ebe57a042.png)
#
# Risk of overfitting:
# * Models can "memorize" the right answer.
# * Inference diﬃcult.
# * Encourages overconﬁdence in model.
#
# This is ultimately a better balance between fitting these dots and fitting another set of dots:
#
# ![image.png](attachment:2070d869-4654-4a29-9ebf-39fb6e01211c.png)
#
# This balance is what we are trying to strike when we build our models.

# %% [markdown]
# We can use the `sklearn.model_selection.train_test_split` command to randomly split the data into subsets. It is an unusual function that returns four values. The `test_size` parameter indicates the portion to save for testing.

# %%
from sklearn.model_selection import train_test_split
featuresTrain, featuresTest, outcomeTrain, outcomeTest = train_test_split(features, 
                                                                          outcome, 
                                                                          test_size = 0.33, 
                                                                          random_state = 42)
featuresTrain.shape
featuresTest.shape
outcomeTrain.shape
outcomeTest.shape
# Out:
# (20100, 18)
# (9900, 18)
# (20100,)
# (9900,)

# %% [markdown]
# Notice the parameter `random_state = 42`. If we didn't include this parameter, each of us would get a different split, resulting in different models. Setting the `random_state` ensures that "randomness" works exactly the same for each of us. It also ensures that your model results will be replicable each time you run your code. (FYI, you can set the `random_state` to whatever number you'd like...42 is my favorite number.)

# %% [markdown]
# ## Building a Decision Tree
#
# ![image.png](attachment:11f8e071-8b01-478d-8ee5-cfe706cd1f9e.png)
#
# * A ﬂowchart-like structure
# * Each internal node represents a test on an attribute
# * Each branch represents the outcome of the test
# * Each leaf node represents a class label
# * The paths from root to leaf represent classiﬁcation rules.
#
# Pros and cons?
# * Simple
# * White-box
# * Sensitive to data ('high variance')
# * May require many levels
# * Generally low accuracy
#
# Let's build the model. There are generally 4 steps:
# ```
# 1. Set-up the model
# 2. Fit the model using the training data
# 3. Use the fitted model to predict outcomes
# 4. Assess the fit
# ```

# %% [markdown]
# **1. Set-up the model:**

# %%
import sklearn.tree
modelTree = sklearn.tree.DecisionTreeClassifier(random_state = 42)

# %% [markdown]
# **2. Fit the model using the training data:**

# %%
resultTree = modelTree.fit(featuresTrain, outcomeTrain)

# %% [markdown]
# To actually see the tree, you can run this code:

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,20))
_ = sklearn.tree.plot_tree(resultTree, feature_names = list(features), filled = True,\
                       class_names = modelTree.classes_.tolist(), max_depth = 2)

# To save the tree as a png file:
# fig.savefig("decision_tree.png")

# %% [markdown]
# You can also get a text printout of the entire tree using this command:

# %%
tree_rules = sklearn.tree.export_text(modelTree, feature_names=list(features))
print(tree_rules)
# Out:
# |--- Pay_0_Delay2 <= 0.50
# |   |--- Pay_Amt1 <= 21.00
# |   |   |--- Pay_0_Delay3 <= 0.50
# |   |   |   |--- Limit_Bal <= 45000.00
# |   |   |   |   |--- Bill_Amt1 <= 3936.00
# |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= 1476.00
# |   |   |   |   |   |   |   |--- Pay_0_unknown <= 0.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1054.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -1243.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -1243.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 912.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  912.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1054.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Pay_0_unknown >  0.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  1476.00
# |   |   |   |   |   |   |   |--- Age <= 43.00
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Age >  43.00
# |   |   |   |   |   |   |   |   |--- Age <= 47.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Age >  47.50
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1948.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1948.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= -203.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= -1200.00
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  -1200.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  -203.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 990.00
# |   |   |   |   |   |   |   |   |--- Pay_0_unknown <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 35.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 35000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  35000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  35.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Pay_0_unknown >  0.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 33.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  33.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -2.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  990.00
# |   |   |   |   |   |   |   |   |--- Age <= 47.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  47.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 3179.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  3179.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Bill_Amt1 >  3936.00
# |   |   |   |   |   |--- Pay_0_Delay4 <= 0.50
# |   |   |   |   |   |   |--- Age <= 51.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 8304.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 7076.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 5292.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  5292.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Age >  23.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  7076.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  8304.50
# |   |   |   |   |   |   |   |   |--- Pay_0_Delay5 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 15000.00
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  15000.00
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Pay_0_Delay5 >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Age >  51.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 24488.50
# |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 7867.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 7079.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  7079.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  7867.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 54.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  54.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  24488.50
# |   |   |   |   |   |   |   |   |--- Age <= 55.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Age >  55.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |--- Pay_0_Delay4 >  0.50
# |   |   |   |   |   |   |--- Age <= 44.50
# |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 24454.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 18505.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  18505.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  24454.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Age >  44.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 17114.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  17114.50
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |--- Limit_Bal >  45000.00
# |   |   |   |   |--- Pay_0_Delay4 <= 0.50
# |   |   |   |   |   |--- Pay_0_Delay1 <= 0.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= 224192.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 799.50
# |   |   |   |   |   |   |   |   |--- Age <= 62.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 23
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |--- Age >  62.50
# |   |   |   |   |   |   |   |   |   |--- Pay_0_ontime <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Pay_0_ontime >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 394.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  394.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  799.50
# |   |   |   |   |   |   |   |   |--- Pay_0_ontime <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 645000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_0_Delay7 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- Pay_0_Delay7 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  645000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Pay_0_ontime >  0.50
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 3652.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  3652.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  224192.00
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Pay_0_Delay1 >  0.50
# |   |   |   |   |   |   |--- Age <= 42.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 21005.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 6254.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Age >  36.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  6254.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 55000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  55000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -2.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Age >  26.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -2.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 11556.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  11556.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  21005.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 155000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 22119.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 55000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  55000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  22119.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 23508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  23508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  155000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 51889.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  51889.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 185000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  185000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |--- Age >  42.50
# |   |   |   |   |   |   |   |--- Age <= 60.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -206.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -206.00
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 57.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Age >  57.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |--- Age >  60.50
# |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 175000.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 5786.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  5786.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  175000.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 430000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  430000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |--- Pay_0_Delay4 >  0.50
# |   |   |   |   |   |--- Pay_Amt1 <= 1.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= 46736.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 35335.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  35335.00
# |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  46736.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Pay_Amt1 >  1.50
# |   |   |   |   |   |   |--- class: Paid
# |   |   |--- Pay_0_Delay3 >  0.50
# |   |   |   |--- Bill_Amt1 <= 18723.50
# |   |   |   |   |--- Bill_Amt1 <= 900.00
# |   |   |   |   |   |--- Age <= 27.50
# |   |   |   |   |   |   |--- Age <= 23.00
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Age >  23.00
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Age >  27.50
# |   |   |   |   |   |   |--- Age <= 44.50
# |   |   |   |   |   |   |   |--- Age <= 37.00
# |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Age >  37.00
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Age >  44.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |--- Bill_Amt1 >  900.00
# |   |   |   |   |   |--- Age <= 48.00
# |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1825.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1225.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1225.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  1825.00
# |   |   |   |   |   |   |   |   |--- Age <= 35.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Age >  35.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 39.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  39.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Age >  48.00
# |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |--- Limit_Bal <= 40000.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Limit_Bal >  40000.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 205000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  205000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |--- Bill_Amt1 >  18723.50
# |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |--- Age <= 29.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 19776.00
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  19776.00
# |   |   |   |   |   |   |   |--- Limit_Bal <= 70000.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Limit_Bal >  70000.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 85000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  85000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Age >  29.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 24812.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  24812.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 31241.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  31241.50
# |   |   |   |   |   |   |   |   |--- Age <= 37.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  37.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 49166.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  49166.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |--- Bill_Amt1 <= 49579.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 27110.00
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  27110.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 34153.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 28373.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  28373.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 23.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  23.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  34153.00
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |--- Bill_Amt1 >  49579.00
# |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 104051.50
# |   |   |   |   |   |   |   |   |--- Age <= 27.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  27.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  104051.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 135000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  135000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |--- Pay_Amt1 >  21.00
# |   |   |--- Limit_Bal <= 75000.00
# |   |   |   |--- Pay_0_Delay3 <= 0.50
# |   |   |   |   |--- Pay_0_Delay1 <= 0.50
# |   |   |   |   |   |--- Limit_Bal <= 45000.00
# |   |   |   |   |   |   |--- Pay_Amt1 <= 2344.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 40731.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 15409.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 15259.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Age >  51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  15259.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  15409.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 19192.00
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- Age >  35.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  19192.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 19236.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  19236.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  40731.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Pay_Amt1 >  2344.00
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5001.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 13000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 6220.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 3118.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  3118.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  6220.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 2900.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  2900.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  13000.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 2414.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  2414.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  5001.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 33095.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5709.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  5709.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5862.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  5862.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  33095.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Limit_Bal >  45000.00
# |   |   |   |   |   |   |--- Pay_Amt1 <= 1106.50
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1067.00
# |   |   |   |   |   |   |   |   |--- Age <= 57.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 865.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  865.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  57.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  1067.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 2994.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  2994.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1098.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1098.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Pay_Amt1 >  1106.50
# |   |   |   |   |   |   |   |--- Age <= 57.50
# |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 15450.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- Age >  51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  15450.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 15987.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  15987.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 8071.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 7416.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  7416.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  8071.00
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- Age >  28.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |--- Age >  57.50
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Pay_0_Delay1 >  0.50
# |   |   |   |   |   |--- Bill_Amt1 <= 512.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= -677.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  -677.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= -481.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  -481.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 693.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 42.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  42.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  693.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -6.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -127.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -127.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -6.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- Bill_Amt1 >  512.00
# |   |   |   |   |   |   |--- Pay_Amt1 <= 3693.00
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 3146.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 4274.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  4274.50
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1403.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1403.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 15000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  15000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  3146.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Pay_Amt1 >  3693.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 3260.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 15000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  15000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  3260.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 23864.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  23864.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 25.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  25.00
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- Pay_0_Delay3 >  0.50
# |   |   |   |   |--- Age <= 39.50
# |   |   |   |   |   |--- Pay_Amt1 <= 226.50
# |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |--- Pay_Amt1 >  226.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= 81007.00
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  81007.00
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Age >  39.50
# |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 35000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  35000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |--- Limit_Bal >  75000.00
# |   |   |   |--- Pay_0_Delay3 <= 0.50
# |   |   |   |   |--- Pay_0_Delay1 <= 0.50
# |   |   |   |   |   |--- Bill_Amt1 <= 2036.50
# |   |   |   |   |   |   |--- Limit_Bal <= 235000.00
# |   |   |   |   |   |   |   |--- Pay_0_unknown <= 0.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1988.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 784.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 751.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  751.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  784.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1988.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 2004.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_other >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  2004.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 2034.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  2034.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Pay_0_unknown >  0.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 753.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 738.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 296.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  296.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  738.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  753.00
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 95000.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 85000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  85000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  95000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 394.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  394.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Limit_Bal >  235000.00
# |   |   |   |   |   |   |   |--- Age <= 24.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 981.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  981.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1243.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1243.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Age >  24.50
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 25.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  25.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 3136.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1944.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  1944.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  3136.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 2018.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  2018.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Bill_Amt1 >  2036.50
# |   |   |   |   |   |   |--- Pay_0_Delay4 <= 0.50
# |   |   |   |   |   |   |   |--- Limit_Bal <= 245000.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 130100.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 145000.00
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 71.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 31
# |   |   |   |   |   |   |   |   |   |   |--- Age >  71.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  145000.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 10720.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  10720.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  130100.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 130344.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  130344.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 13825.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 31
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  13825.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- Limit_Bal >  245000.00
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 255183.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 8333.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 8308.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  8308.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  8333.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 11001.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  11001.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  255183.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 25.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 332047.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  332047.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- Age >  25.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 355000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  355000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- Pay_0_Delay4 >  0.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |--- Pay_0_Delay1 >  0.50
# |   |   |   |   |   |--- Bill_Amt1 <= 31823.50
# |   |   |   |   |   |   |--- Pay_Amt1 <= 2208.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= -2217.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  -2217.50
# |   |   |   |   |   |   |   |   |--- Age <= 57.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 125000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1680.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1680.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  125000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 328.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  328.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |--- Age >  57.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 65.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  65.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Pay_Amt1 >  2208.50
# |   |   |   |   |   |   |   |--- Age <= 49.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 505000.00
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 325000.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 315000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  315000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  325000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  505000.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 29.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  29.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Age >  49.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= -239.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 39187.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  39187.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  -239.00
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 2869.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 2552.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  2552.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  2869.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 490000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  490000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- Bill_Amt1 >  31823.50
# |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |--- Limit_Bal <= 295000.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 12900.00
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 145000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  145000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 159.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  159.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  12900.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Limit_Bal >  295000.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 205964.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5006.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 38.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 230000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  230000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Age >  38.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Age >  43.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  5006.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 39.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 172730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  172730.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Age >  39.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 7275.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  7275.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  205964.00
# |   |   |   |   |   |   |   |   |--- Age <= 41.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 34.50
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 10118.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# ...
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  1723.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Pay_Amt1 >  1962.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 1641.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  1641.50
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Bill_Amt1 >  1989.50
# |   |   |   |   |   |--- class: Paid
# |   |--- Bill_Amt1 >  2211.50
# |   |   |--- Bill_Amt1 <= 97969.00
# |   |   |   |--- Pay_Amt1 <= 30001.50
# |   |   |   |   |--- Age <= 22.50
# |   |   |   |   |   |--- Bill_Amt1 <= 15027.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 7644.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 7181.50
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  7181.50
# |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  7644.00
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Bill_Amt1 >  15027.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 26675.50
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 2500.00
# |   |   |   |   |   |   |   |   |--- Age <= 21.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Age >  21.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 17736.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 16369.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  16369.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  17736.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  2500.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  26675.50
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 0.50
# |   |   |   |   |   |   |   |   |--- Age <= 21.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  21.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  0.50
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 27755.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  27755.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 30126.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  30126.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 30601.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  30601.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |--- Age >  22.50
# |   |   |   |   |   |--- Pay_Amt1 <= 4075.00
# |   |   |   |   |   |   |--- Marriage_other <= 0.50
# |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 105000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 91382.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  91382.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 96462.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  96462.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  105000.00
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Age <= 45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Age >  45.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 53728.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  53728.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |--- Age <= 52.50
# |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 11356.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  11356.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 8062.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  8062.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 20
# |   |   |   |   |   |   |   |   |--- Age >  52.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 60.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  60.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Marriage_other >  0.50
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 31861.50
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1298.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 2661.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  2661.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1298.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  31861.50
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 3691.00
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 65000.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 42302.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  42302.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  65000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  3691.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Pay_Amt1 >  4075.00
# |   |   |   |   |   |   |--- Pay_Amt1 <= 4950.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 77974.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 155000.00
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 36963.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  36963.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 38975.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  38975.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  155000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  77974.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Pay_Amt1 >  4950.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 26604.50
# |   |   |   |   |   |   |   |   |--- Age <= 23.50
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 25000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  25000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  23.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  26604.50
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 75000.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 24.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Age >  24.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 51235.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  51235.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  75000.00
# |   |   |   |   |   |   |   |   |   |--- Age <= 35.00
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 295000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  295000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  35.00
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 93992.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  93992.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- Pay_Amt1 >  30001.50
# |   |   |   |   |--- Bill_Amt1 <= 15944.50
# |   |   |   |   |   |--- class: Missed
# |   |   |   |   |--- Bill_Amt1 >  15944.50
# |   |   |   |   |   |--- class: Paid
# |   |   |--- Bill_Amt1 >  97969.00
# |   |   |   |--- Bill_Amt1 <= 99865.50
# |   |   |   |   |--- Limit_Bal <= 120000.00
# |   |   |   |   |   |--- Bill_Amt1 <= 99433.00
# |   |   |   |   |   |   |--- Bill_Amt1 <= 98230.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Bill_Amt1 >  98230.50
# |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Bill_Amt1 >  99433.00
# |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Limit_Bal >  120000.00
# |   |   |   |   |   |--- class: Paid
# |   |   |   |--- Bill_Amt1 >  99865.50
# |   |   |   |   |--- Age <= 27.50
# |   |   |   |   |   |--- Bill_Amt1 <= 101415.50
# |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |--- Bill_Amt1 >  101415.50
# |   |   |   |   |   |   |--- Bill_Amt1 <= 111326.50
# |   |   |   |   |   |   |   |--- Limit_Bal <= 130000.00
# |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Limit_Bal >  130000.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 155000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  155000.00
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |--- Bill_Amt1 >  111326.50
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5008.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 1008.00
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 205000.00
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  205000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  1008.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  5008.00
# |   |   |   |   |   |   |   |   |--- Limit_Bal <= 345000.00
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 185000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 7250.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  7250.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  185000.00
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 15800.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  15800.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Limit_Bal >  345000.00
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |--- Age >  27.50
# |   |   |   |   |   |--- Age <= 57.50
# |   |   |   |   |   |   |--- Limit_Bal <= 385000.00
# |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5750.00
# |   |   |   |   |   |   |   |   |--- Age <= 30.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 282155.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 108422.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  108422.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  282155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Age >  30.50
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 138172.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  138172.50
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 <= 197853.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- Bill_Amt1 >  197853.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- Pay_Amt1 >  5750.00
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 <= 5852.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Pay_Amt1 >  5852.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 37.50
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal <= 275000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- Limit_Bal >  275000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- Age >  37.50
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- Marriage_single >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- Limit_Bal >  385000.00
# |   |   |   |   |   |   |   |--- Bill_Amt1 <= 515410.00
# |   |   |   |   |   |   |   |   |--- Age <= 45.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |   |--- Age >  45.50
# |   |   |   |   |   |   |   |   |   |--- Age <= 47.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |   |--- Age >  47.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |   |   |--- Bill_Amt1 >  515410.00
# |   |   |   |   |   |   |   |   |--- Card_Normal <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |   |   |--- Card_Normal >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Missed
# |   |   |   |   |   |--- Age >  57.50
# |   |   |   |   |   |   |--- Age <= 67.50
# |   |   |   |   |   |   |   |--- class: Paid
# |   |   |   |   |   |   |--- Age >  67.50
# |   |   |   |   |   |   |   |--- class: Missed

# %% [markdown]
# **3. Use the fitted model to predict outcomes:**

# %%
predTreeTrain = modelTree.predict(featuresTrain)
predTreeTrain
# Out:
# array(['Missed', 'Paid', 'Missed', ..., 'Paid', 'Missed', 'Missed'],
#       dtype=object)

# %% [markdown]
# **4. Assess the fit:**

# %%
sklearn.metrics.r2_score(outcomeTrain, featuresTrain) # this is wrong
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sklearn.metrics.r2_score(outcomeTrain, featuresTrain) # this is wrong
#
# File /opt/tljh/user/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_regression.py:989, in r2_score(y_true, y_pred, sample_weight, multioutput, force_finite)
#     848 @validate_params(
#     849     {
#     850         "y_true": ["array-like"],
#    (...)
#     868     force_finite=True,
#     869 ):
#     870     """:math:`R^2` (coefficient of determination) regression score function.
#     871
#     872     Best possible score is 1.0 and it can be negative (because the
#    (...)
#     987     -inf
#     988     """
# --> 989     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     990         y_true, y_pred, multioutput
#     991     )
#     992     check_consistent_length(y_true, y_pred, sample_weight)
#     994     if _num_samples(y_pred) < 2:
#
# File /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_regression.py:100, in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      66 """Check that y_true and y_pred belong to the same regression task.
#      67
#      68 Parameters
#    (...)
#      97     correct keyword.
#      98 """
#      99 check_consistent_length(y_true, y_pred)
# --> 100 y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#     101 y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#     103 if y_true.ndim == 1:
#
# File /opt/tljh/user/lib/python3.10/site-packages/sklearn/utils/validation.py:915, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913         array = xp.astype(array, dtype, copy=False)
#     914     else:
# --> 915         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916 except ComplexWarning as complex_warning:
#     917     raise ValueError(
#     918         "Complex data not supported\n{}\n".format(array)
#     919     ) from complex_warning
#
# File /opt/tljh/user/lib/python3.10/site-packages/sklearn/utils/_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File /opt/tljh/user/lib/python3.10/site-packages/pandas/core/series.py:953, in Series.__array__(self, dtype)
#     906 """
#     907 Return the values as a NumPy array.
#     908
#    (...)
#     950       dtype='datetime64[ns]')
#     951 """
#     952 values = self._values
# --> 953 arr = np.asarray(values, dtype=dtype)
#     954 if using_copy_on_write() and astype_is_view(values.dtype, arr.dtype):
#     955     arr = arr.view()
#
# ValueError: could not convert string to float: 'Missed'

# %% [markdown]
# What happened?
#
# Metrics like $R^2$, mean squared error, mean absolute error, etc., make sense for regression, but not classification.
#
# How can we tell if a model is good or bad?
# * Depends on the reference
#   - "Better or worse" more than "good or bad"
# * Depends on the dependent variable
# * Depends on the kind of model
# * Depends on the goal
#
# What outcomes are we trying to predict?

# %%
pd.Series(outcomeTrain).value_counts()
# Out:
# Payment
# Paid      15622
# Missed     4478
# Name: count, dtype: int64

# %% [markdown]
# What did the model predict?

# %%
pd.Series(predTreeTrain).value_counts()
# Out:
# Paid      15597
# Missed     4503
# Name: count, dtype: int64

# %% [markdown]
# So, we know the prediction isn't perfect. But what did it miss? How imperfect?

# %% [markdown]
# ### Confusion Matrix
#
# Check the confusion matrix to assess the model's goodness of fit:

# %%
sklearn.metrics.accuracy_score(outcomeTrain, predTreeTrain)
cmTreeTrain = sklearn.metrics.confusion_matrix(outcomeTrain, predTreeTrain)
sklearn.metrics.ConfusionMatrixDisplay(cmTreeTrain, display_labels = modelTree.classes_).plot()
# Out:
# 0.9976616915422886

# %% [markdown]
# We can quickly look at many metrics with the `classification_report`:

# %%
print(sklearn.metrics.classification_report(outcomeTrain, predTreeTrain))
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.99      1.00      0.99      4478
#         Paid       1.00      1.00      1.00     15622
#
#     accuracy                           1.00     20100
#    macro avg       1.00      1.00      1.00     20100
# weighted avg       1.00      1.00      1.00     20100

# %% [markdown]
# * Out of all the people that the model predicted Missed, 99% actually Missed
# * Out of all the people that actually Missed, the model predicted 100% of them
# * Out of all the people that the model predicted Paid, 100% actually Paid
# * Out of all the people that actually Paid, the model predicted 100% of them
# * Support tells us how many of each case are in the data

# %% [markdown]
# It's no surprise that the model does well on the training data that was used to build it.
#
# The real "test" (forgive the pun) is to see how the model fits the test data to assess overfitting:

# %%
# First create the predictions on the test data
predTreeTest = modelTree.predict(featuresTest)

# Then assess the fit
cmTreeTest = sklearn.metrics.confusion_matrix(outcomeTest, predTreeTest)
sklearn.metrics.ConfusionMatrixDisplay(cmTreeTest, display_labels = modelTree.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest, predTreeTest))
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.36      0.40      0.38      2158
#         Paid       0.83      0.80      0.81      7742
#
#     accuracy                           0.71      9900
#    macro avg       0.59      0.60      0.60      9900
# weighted avg       0.72      0.71      0.72      9900

# %% [markdown]
# * Out of all the people that the model predicted Missed, 36% actually Missed
# * Out of all the people that actually Missed, the model predicted 40% of them
# * Out of all the people that the model predicted Paid, 83% actually Paid
# * Out of all the people that actually Paid, the model predicted 80% of them
# * The overall accuracy is 71%

# %% [markdown]
# How did the model do at predicting new data?
# * Bad overfitting
# * Decision trees, while nice to look at, are terrible about overfit

# %% [markdown]
# ## Random Forests
#
# The steps are the same for random forests as they are for decision trees, with the exception that you use `sklearn.ensemble.RandomForestClassifier` to build the model:

# %%
# 1. Set-up the model
import sklearn.ensemble
modelForest = sklearn.ensemble.RandomForestClassifier(random_state = 42)

# 2. Fit the model using the training data
resultForest = modelForest.fit(featuresTrain, outcomeTrain)

# 3. Predict outcomes from the training and testing data
predForestTrain = modelForest.predict(featuresTrain)
predForestTest = modelForest.predict(featuresTest)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain, predForestTrain))
cmForestTest = sklearn.metrics.confusion_matrix(outcomeTest, predForestTest)
sklearn.metrics.ConfusionMatrixDisplay(cmForestTest, display_labels = modelForest.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest, predForestTest))
# Out:
#               precision    recall  f1-score   support
#
#       Missed       1.00      0.99      0.99      4478
#         Paid       1.00      1.00      1.00     15622
#
#     accuracy                           1.00     20100
#    macro avg       1.00      1.00      1.00     20100
# weighted avg       1.00      1.00      1.00     20100
#               precision    recall  f1-score   support
#
#       Missed       0.58      0.36      0.44      2158
#         Paid       0.84      0.93      0.88      7742
#
#     accuracy                           0.80      9900
#    macro avg       0.71      0.64      0.66      9900
# weighted avg       0.78      0.80      0.79      9900

# %% [markdown]
# ## Support Vector Machines
#
# Now that you've seen how to build Decision Tree and Random Forest models, see if you can figure out how to build a Support Vector Machine model. You'll need to import `sklearn.svm` and the function is called `SVC()` (which stands for support vector classifier). Once again, use a `random_state` of 42.
#
# Is your model better or worse than the previous 2 models?

# %%
# 1. Set-up the model
import sklearn.svm
modelSVM = sklearn.svm.SVC(random_state = 42)

# 2. Fit the model using the training data
resultSVM = modelSVM.fit(featuresTrain, outcomeTrain)

# 3. Predict outcomes from the training and testing data
predSVMTrain = modelSVM.predict(featuresTrain)
predSVMTest = modelSVM.predict(featuresTest)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain, predSVMTrain))
cmSVMTest = sklearn.metrics.confusion_matrix(outcomeTest, predSVMTest)
sklearn.metrics.ConfusionMatrixDisplay(cmSVMTest, display_labels = modelSVM.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest, predSVMTest))
# Out:
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       Missed       0.00      0.00      0.00      4478
#         Paid       0.78      1.00      0.87     15622
#
#     accuracy                           0.78     20100
#    macro avg       0.39      0.50      0.44     20100
# weighted avg       0.60      0.78      0.68     20100
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/tljh/user/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#       Missed       0.00      0.00      0.00      2158
#         Paid       0.78      1.00      0.88      7742
#
#     accuracy                           0.78      9900
#    macro avg       0.39      0.50      0.44      9900
# weighted avg       0.61      0.78      0.69      9900

# %% [markdown]
# ## Scaling Your Features
#
# You likely got warning messages when running your Support Vector Machine model because the model had difficulty predicting a missed payment. Part of this is due to the fact that the features are using different scales...for example, `Limit_Bal` ranges from 10,000 to 1,000,000 whereas `Age` ranges from 21 to 79.
#
# One way to fix this is to normalize your features so that they are all on the same scale. A very common way to do this is to convert all features to values between 0 and 1 with the following formula:
#
# $$
# X_{\text{scaled}} = \frac{X - X_{\text{min}}}{X_{\text{max}} - X_{\text{min}}}
# $$
#
# We can use the `MinMaxScaler()` in `sklearn.preprocessing` to do this:

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
featuresTrain_norm = scaler.fit_transform(featuresTrain) #you fit to the training features
featuresTest_norm = scaler.transform(featuresTest)       #you only transform the test features

# %% [markdown]
# Now, we can rerun the model using `featuresTrain_norm` instead of `featuresTrain` and we can get predictions using the normalized training and test data.
#
# Copy/paste your SVM model from above and edit it to use the normalized features. Did you get better results?

# %%
# 1. Set-up the model
modelSVMn = sklearn.svm.SVC(random_state = 42)

# 2. Fit the model using the training data
resultSVMn = modelSVMn.fit(featuresTrain_norm, outcomeTrain)

# 3. Predict outcomes from the training and testing data
predSVMTrainn = modelSVMn.predict(featuresTrain_norm)
predSVMTestn = modelSVMn.predict(featuresTest_norm)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain, predSVMTrainn))
cmSVMTestn = sklearn.metrics.confusion_matrix(outcomeTest, predSVMTestn)
sklearn.metrics.ConfusionMatrixDisplay(cmSVMTestn, display_labels = modelSVMn.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest, predSVMTestn))
# Out:
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.33      0.45      4478
#         Paid       0.83      0.96      0.89     15622
#
#     accuracy                           0.82     20100
#    macro avg       0.77      0.64      0.67     20100
# weighted avg       0.80      0.82      0.79     20100
#               precision    recall  f1-score   support
#
#       Missed       0.70      0.32      0.44      2158
#         Paid       0.84      0.96      0.89      7742
#
#     accuracy                           0.82      9900
#    macro avg       0.77      0.64      0.67      9900
# weighted avg       0.80      0.82      0.79      9900

# %% [markdown]
# Note: Because Decision Trees and Random Forests are split on each feature itself and not compared to other features, it is generally preferred to keep them un-scaled and in their original state.

# %% [markdown]
# ## Try Another...
#
# Instead of repeating the class exercise, use the 3 models we covered in class to try to classify the Species of flower in the data set, "Iris.csv":

# %%
iris = pd.read_csv("Iris.csv")
iris
iris.dtypes
iris.isna().sum()
iris.describe()
iris["Species"].value_counts()
iris["Petal.Shape"].value_counts()
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species  \
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#     Petal.Shape
# 0         round
# 1        pointy
# 2        pointy
# 3         round
# 4         round
# ..          ...
# 145      pointy
# 146      pointy
# 147       round
# 148       round
# 149      pointy
#
# [150 rows x 6 columns]
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# Petal.Shape      object
# dtype: object
# Sepal.Length    0
# Sepal.Width     0
# Petal.Length    0
# Petal.Width     0
# Species         0
# Petal.Shape     0
# dtype: int64
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000
# Species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64
# Petal.Shape
# round     79
# pointy    71
# Name: count, dtype: int64

# %% [markdown]
# ### Set up your Outcome and Features

# %%
outcome1 = iris["Species"]
numericFeatures1 = iris[["Sepal.Length", "Sepal.Width", "Petal.Length", "Petal.Width"]]
dummyShape = pd.get_dummies(iris["Petal.Shape"], prefix = "Shape", drop_first = True)
features1 = pd.concat([numericFeatures1, dummyShape], axis = 1)
outcome1
features1
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: Species, Length: 150, dtype: object
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  Shape_round
# 0             5.1          3.5           1.4          0.2         True
# 1             4.9          3.0           1.4          0.2        False
# 2             4.7          3.2           1.3          0.2        False
# 3             4.6          3.1           1.5          0.2         True
# 4             5.0          3.6           1.4          0.2         True
# ..            ...          ...           ...          ...          ...
# 145           6.7          3.0           5.2          2.3        False
# 146           6.3          2.5           5.0          1.9        False
# 147           6.5          3.0           5.2          2.0         True
# 148           6.2          3.4           5.4          2.3         True
# 149           5.9          3.0           5.1          1.8        False
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Partition the Data

# %%
from sklearn.model_selection import train_test_split
featuresTrain1, featuresTest1, outcomeTrain1, outcomeTest1 = train_test_split(features1, outcome1, test_size = 0.33, random_state = 42)

# %% [markdown]
# ### Decision Tree

# %%
# 1. Set-up the model
import sklearn.tree
modelTree1 = sklearn.tree.DecisionTreeClassifier(random_state = 42)

# 2. Fit the model using the training data
resultTree1 = modelTree1.fit(featuresTrain1, outcomeTrain1)

# 3. Predict outcomes from the training and testing data
predTreeTrain1 = modelTree1.predict(featuresTrain1)
predTreeTest1 = modelTree1.predict(featuresTest1)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain1, predTreeTrain1))
cmTreeTest1 = sklearn.metrics.confusion_matrix(outcomeTest1, predTreeTest1)
sklearn.metrics.ConfusionMatrixDisplay(cmTreeTest1, display_labels = modelTree1.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest1, predTreeTest1))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        31
#   versicolor       1.00      1.00      1.00        35
#    virginica       1.00      1.00      1.00        34
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %% [markdown]
# ### Random Forest

# %%
# 1. Set-up the model
import sklearn.ensemble
modelForest1 = sklearn.ensemble.RandomForestClassifier(random_state = 42)

# 2. Fit the model using the training data
resultForest1 = modelForest1.fit(featuresTrain1, outcomeTrain1)

# 3. Predict outcomes from the training and testing data
predForestTrain1 = modelForest1.predict(featuresTrain1)
predForestTest1 = modelForest1.predict(featuresTest1)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain1, predForestTrain1))
cmForestTest1 = sklearn.metrics.confusion_matrix(outcomeTest1, predForestTest1)
sklearn.metrics.ConfusionMatrixDisplay(cmForestTest1, display_labels = modelForest1.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest1, predForestTest1))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        31
#   versicolor       1.00      1.00      1.00        35
#    virginica       1.00      1.00      1.00        34
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50

# %% [markdown]
# ### Support Vector Machine

# %%
# Normalize the features
featuresTrain1_norm = scaler.fit_transform(featuresTrain1)
featuresTest1_norm = scaler.fit_transform(featuresTest1)

# 1. Set-up the model
modelSVM1 = sklearn.svm.SVC(random_state = 42)

# 2. Fit the model using the training data
resultSVM1 = modelSVM1.fit(featuresTrain1_norm, outcomeTrain1)

# 3. Predict outcomes from the training and testing data
predSVMTrain1 = modelSVM1.predict(featuresTrain1_norm)
predSVMTest1 = modelSVM1.predict(featuresTest1_norm)

# 4. Assess the fit
print(sklearn.metrics.classification_report(outcomeTrain1, predSVMTrain1))
cmSVMTest1 = sklearn.metrics.confusion_matrix(outcomeTest1, predSVMTest1)
sklearn.metrics.ConfusionMatrixDisplay(cmSVMTest1, display_labels = modelSVM1.classes_).plot()
print(sklearn.metrics.classification_report(outcomeTest1, predSVMTest1))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        31
#   versicolor       0.97      0.91      0.94        35
#    virginica       0.92      0.97      0.94        34
#
#     accuracy                           0.96       100
#    macro avg       0.96      0.96      0.96       100
# weighted avg       0.96      0.96      0.96       100
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       0.94      1.00      0.97        15
#    virginica       1.00      0.94      0.97        16
#
#     accuracy                           0.98        50
#    macro avg       0.98      0.98      0.98        50
# weighted avg       0.98      0.98      0.98        50
